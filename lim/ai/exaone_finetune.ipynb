# %%
# gitsetup.ipynb에서 세팅 완료 후
# exaone_finetune.ipynb에서 이거 실행해보기

import os
print(os.getcwd())          # 현재 경로 확인
# !git status                  # git 살아있는지 확인
# !echo $COLAB_BACKEND_PORT   # 런타임 포트 확인
